# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanunchida-May/data_viz_2022/blob/main/Pandas102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/dataviz_2022'
# Out:
# Mounted at /content/drive

# %%
data_df = pd.read_csv(covid_file_path)

# %%
data_df
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %%
data_df.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %% [markdown]
# ตรวจสอบค่าใน Column

# %%
set(data_df['province_of_onset']) #setคือสมาชิกหน้าตาเหมือนกันจะนับเเค่ 1 ตัว
# Out:
# {nan,
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'คลองใหญ่',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชากบก',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บางบุตร',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พม่า',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มาบตาพุด',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สมุุทรสงคราม',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
# ...

# %%
len('สมุทรสงคราม')
# Out:
# 11

# %%
'สมุทรสงคราม'[2]
# Out:
# 'ุ'

# %%
'สมุทรสงคราม'[3]
# Out:
# 'ท'

# %% [markdown]
# #ต่อตาราง
# * ต่อในเเนวเเกน y(เพิ่มจำนวนข้อมูล)
# * ต่อในเเนวเเกน x(เพิ่มรายละเอียดของข้อมูล)

# %%
ฺBKK = data_df[data_df['province_of_onset']=='กรุงเทพมหานคร']
BKK.head()
# Out:
#   File "<ipython-input-45-fb5e48f097d3>", line 1
#     ฺBKK = data_df[data_df['province_of_onset']=='กรุงเทพมหานคร']
#        ^
# SyntaxError: invalid character in identifier

# %%
KKC = data_df[data_df['province_of_onset']=='ขอนเเก่น']
KKC.head()
# Out:
# Empty DataFrame
# Columns: [No., announce_date, notification_date, sex, age, nationality, province_of_isolation, province_of_onset, district_of_onset, risk]
# Index: []

# %% [markdown]
# ##ต่อตารางให้เป็นข้อมูล 2 จังหวัด

# %%
dataBKKKKC = pd.concat([BKK,KKC])
dataBKKKKC
# Out:
#          No.  ...                                           risk
# 0          1  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 5          6  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                            ...
# 12616  12617  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12617  12618  ...   ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 12618  12619  ...   ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 12619  12620  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12647  12648  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
#
# [2789 rows x 10 columns]

# %% [markdown]
# ##ถ้าเอาตารางไม่เหมือนกันมา concat กัน

# %%
BKK2 = data_df[data_df['province_of_onset']=='กรุงเทพมหานคร'][['sex','age','nationality']]
BKK2.head()
# Out:
#     sex   age nationality
# 0  หญิง  61.0       China
# 1  หญิง  74.0       China
# 3   ชาย  68.0       China
# 4  หญิง  66.0       China
# 5  หญิง  33.0       China

# %%
KKC2 = data_df[data_df['province_of_onset']=='ขอนเเก่น'][['age','nationality','sex']]
KKC2.head()
# Out:
# Empty DataFrame
# Columns: [age, nationality, sex]
# Index: []

# %%
pd.concat([BKK2,KKC2])
# Out:
#         sex   age nationality
# 0      หญิง  61.0       China
# 1      หญิง  74.0       China
# 3       ชาย  68.0       China
# 4      หญิง  66.0       China
# 5      หญิง  33.0       China
# ...     ...   ...         ...
# 12616   ชาย  26.0    Thailand
# 12617  หญิง  12.0     Ireland
# 12618  หญิง  34.0    Pakistan
# 12619  หญิง  19.0    Thailand
# 12647   ชาย  42.0    Thailand
#
# [2789 rows x 3 columns]

# %%
KKC = data_df[data_df[data_df['province_of_onset']=='ขอนเเก่น']
